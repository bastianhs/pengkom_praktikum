# %%
# NIM/Nama: 19622138/Bastian Hendramukti Suryapratama
# Tanggal: 16 November 2022
# Deskripsi: Penyelesaian problem 2

# PROBLEM_2

# KAMUS
# df: dataframe
# filt: series

# ALGORITMA
import pandas as pd
df = pd.read_csv("H05.csv")

# %%
# 1. Nilai matematika, fisika, dan kimia milik Tuan Leo
filt = (df["nama"] == "Tuan Leo")
df.loc[filt, ["nama", "nilai_mat", "nilai_fis", "nilai_kim"]]
# Out:
#           nama  nilai_mat  nilai_fis  nilai_kim
# 3513  Tuan Leo      96.78      30.53      62.23

# %%
# 2. Mahasiswa dengan nilai fisika tertinggi
filt = (df["nilai_fis"] == df["nilai_fis"].max())
df.loc[filt, "nama"]
# Out:
# 1936    Yuniar Fazriani Rusmana
# Name: nama, dtype: object

# %%
# 3. 10 Mahasiswa dengan nilai kimia tertinggi
df.sort_values(by="nilai_kim", ascending=False).head(10)["nama"]
# Out:
# 2554        Faathir Reza Avicena
# 2779        Dinda A A Z Mundakir
# 3544          Tammya Ayu Purnomo
# 4934      Alyssa Nadhira Windari
# 1137            Izni Nur Ibrahim
# 2262        Rinaldi Oky Setiawan
# 4070        Ias Azhari Rezkyarno
# 2945             Klara Petra T T
# 1788    Naudy Germanimo Laksmana
# 1310         Mardliyahtur Rohmah
# Name: nama, dtype: object

# %%
# 4. Banyaknya nilai matematika di bawah 50
filt = df["nilai_mat"] < 50
df.loc[filt].shape[0]
# Out:
# 329

# %%
# 5. Banyaknya mahasiswa FMIPA
df["fakultas"].value_counts().loc["FMIPA"]
# Out:
# 627
